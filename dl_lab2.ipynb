# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def train_and_plot(model, name):
    print(f"\nTraining {name}\n")
    model.compile(
        optimizer="adam",
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        batch_size=128,
        validation_data=(x_test, y_test),
        verbose=1
    )
    plt.figure()
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title(f"Loss {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(["Training Loss", "Validation Loss"])
    plt.show()

    plt.figure()
    plt.plot(history.history["accuracy"])
    plt.plot(history.history["val_accuracy"])
    plt.title(f"Accuracy {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend(["Training Accuracy", "Validation Accuracy"])
    plt.show()
baseline_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    Dense(10, activation="softmax")
])
train_and_plot(baseline_model, "Baseline")
batchnorm_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    BatchNormalization(),
    Dense(10, activation="softmax")
])
train_and_plot(batchnorm_model, "Batch Normalization")
l2_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu", kernel_regularizer=l2(0.001)),
    Dense(10, activation="softmax")
])
train_and_plot(l2_model, "L2 Regularization")
dropout_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

train_and_plot(dropout_model, "Dropout")
# Out:
# Training Baseline
#
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8325 - loss: 0.6072 - val_accuracy: 0.9429 - val_loss: 0.1976
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9486 - loss: 0.1783 - val_accuracy: 0.9599 - val_loss: 0.1341
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9637 - loss: 0.1264 - val_accuracy: 0.9674 - val_loss: 0.1092
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9753 - loss: 0.0898 - val_accuracy: 0.9727 - val_loss: 0.0923
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9797 - loss: 0.0739 - val_accuracy: 0.9728 - val_loss: 0.0906
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9821 - loss: 0.0608 - val_accuracy: 0.9758 - val_loss: 0.0807
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9867 - loss: 0.0499 - val_accuracy: 0.9755 - val_loss: 0.0795
# Epoch 8/10
# ...
